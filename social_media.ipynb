# %% [markdown]
# <a href="https://colab.research.google.com/github/patilhumesh88-spec/data_projects_01/blob/NLP/social_media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
