# %%
import matplotlib as pyplot
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/spotify_2014_2020_dataset.csv")

# %%
df.head()
# Out:
#                  Track_ID      Track_Name  Duration_Min  \
# 0  6dBUzqjtbnIa1TwYbyw5CM     Lovers Rock          3.57
# 1  5J4ZkQpzMUFojo1CtAZYpn  Love Me Harder          3.94
# 2  2e3Ea0o24lReQFR4FA7yXH      Love Yourz          3.52
# 3  6nGeLlakfzlBcFdZXteDq7      Love Story          5.27
# 4  5BJSZocnCeSNeYMj3iVqM7   Love Runs Out          3.74
#
#                      Artists Release_Date  Year Query
# 0                    TV Girl     6/5/2014  2014  love
# 1  Ariana Grande, The Weeknd    8/22/2014  2014  love
# 2                    J. Cole    12/9/2014  2014  love
# 3                     Indila     1/1/2014  2014  love
# 4                OneRepublic     1/1/2014  2014  love

# %%
df.columns
# Out:
# Index(['Track_ID', 'Track_Name', 'Duration_Min', 'Artists', 'Release_Date',
#        'Year', 'Query'],
#       dtype='object')

# %%
df.tail()
# Out:
#                     Track_ID           Track_Name  Duration_Min  \
# 1696  2fyDWKsx5904KnZMGllmAv        A Sad Cartoon          5.26
# 1697  1y2GDXFvtHPbCkHFYg49Gn        Sudden Desire          3.13
# 1698  5UBonaClAZVfzxJNn8nnhh    Brown Sleep Noise          4.13
# 1699  2pgDBO0ZAgvye7joSmdDm8  SAD GIRLZ LUV MONEY          3.27
# 1700  7lidXGPXPYLNThITAOTlkK    You should be sad          3.42
#
#               Artists Release_Date  Year Query
# 1696           Loathe     2/7/2020  2020   sad
# 1697  Hayley Williams     5/8/2020  2020   sad
# 1698    Sleep Miracle   12/16/2020  2020   sad
# 1699   Amaarae, MOLIY   11/12/2020  2020   sad
# 1700           Halsey    1/17/2020  2020   sad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1701 entries, 0 to 1700
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Track_ID      1701 non-null   object
#  1   Track_Name    1701 non-null   object
#  2   Duration_Min  1701 non-null   float64
#  3   Artists       1701 non-null   object
#  4   Release_Date  1701 non-null   object
#  5   Year          1701 non-null   int64
#  6   Query         1701 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 93.2+ KB

# %%
df.describe()
# Out:
#        Duration_Min         Year
# count   1701.000000  1701.000000
# mean       4.268595  2016.513815
# std        5.260055     1.854553
# min        3.000000  2014.000000
# 25%        3.460000  2015.000000
# 50%        3.830000  2016.000000
# 75%        4.320000  2018.000000
# max      180.470000  2020.000000

# %%
df.shape
# Out:
# (1701, 7)

# %%
useless=df[["Track_ID","Duration_Min"]]

# %%
df.loc[0]
# Out:
# Track_ID        6dBUzqjtbnIa1TwYbyw5CM
# Track_Name                 Lovers Rock
# Duration_Min                      3.57
# Artists                        TV Girl
# Release_Date                  6/5/2014
# Year                              2014
# Query                             love
# Name: 0, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'Lovers Rock'

# %%
df.iloc[0:7]
# Out:
#                  Track_ID               Track_Name  Duration_Min  \
# 0  6dBUzqjtbnIa1TwYbyw5CM              Lovers Rock          3.57
# 1  5J4ZkQpzMUFojo1CtAZYpn           Love Me Harder          3.94
# 2  2e3Ea0o24lReQFR4FA7yXH               Love Yourz          3.52
# 3  6nGeLlakfzlBcFdZXteDq7               Love Story          5.27
# 4  5BJSZocnCeSNeYMj3iVqM7            Love Runs Out          3.74
# 5  48td6xvpokdYwvbl3JIiXP  Love Never Felt So Good          4.11
# 6  3sslYZcFKtUvIEWN9lADgr   First Love/Late Spring          4.64
#
#                               Artists Release_Date  Year Query
# 0                             TV Girl     6/5/2014  2014  love
# 1           Ariana Grande, The Weeknd    8/22/2014  2014  love
# 2                             J. Cole    12/9/2014  2014  love
# 3                              Indila     1/1/2014  2014  love
# 4                         OneRepublic     1/1/2014  2014  love
# 5  Michael Jackson, Justin Timberlake     5/9/2014  2014  love
# ...

# %%
df.loc[0:6,["Track_ID","Duration_Min"]]
# Out:
#                  Track_ID  Duration_Min
# 0  6dBUzqjtbnIa1TwYbyw5CM          3.57
# 1  5J4ZkQpzMUFojo1CtAZYpn          3.94
# 2  2e3Ea0o24lReQFR4FA7yXH          3.52
# 3  6nGeLlakfzlBcFdZXteDq7          5.27
# 4  5BJSZocnCeSNeYMj3iVqM7          3.74
# 5  48td6xvpokdYwvbl3JIiXP          4.11
# 6  3sslYZcFKtUvIEWN9lADgr          4.64

# %%
df.iat[2,3]
# Out:
# 'J. Cole'

# %%
df.at[0,"Duration_Min"]
# Out:
# np.float64(3.57)

# %%
df.head()
# Out:
#                  Track_ID      Track_Name  Duration_Min  \
# 0  6dBUzqjtbnIa1TwYbyw5CM     Lovers Rock          3.57
# 1  5J4ZkQpzMUFojo1CtAZYpn  Love Me Harder          3.94
# 2  2e3Ea0o24lReQFR4FA7yXH      Love Yourz          3.52
# 3  6nGeLlakfzlBcFdZXteDq7      Love Story          5.27
# 4  5BJSZocnCeSNeYMj3iVqM7   Love Runs Out          3.74
#
#                      Artists Release_Date  Year Query
# 0                    TV Girl     6/5/2014  2014  love
# 1  Ariana Grande, The Weeknd    8/22/2014  2014  love
# 2                    J. Cole    12/9/2014  2014  love
# 3                     Indila     1/1/2014  2014  love
# 4                OneRepublic     1/1/2014  2014  love

# %%
df[df["Duration_Min"]==3.00]
# Out:
#                     Track_ID                       Track_Name  Duration_Min  \
# 896   6pnD89Q888HUHhcwQUTky8                      Free Animal           3.0
# 1064  2wxfu24GQpEZQrjDJm5Ac1               Every Little Thing           3.0
# 1281  0V4aRCAMBblWlRGTjiyMRR  Fetish Remix (feat. Young Thug)           3.0
#
#                    Artists Release_Date  Year  Query
# 896            Foreign Air    9/23/2016  2016   rock
# 1064          Carly Pearce   10/13/2017  2017    sad
# 1281  Lil Keed, Young Thug    9/14/2018  2018  remix

# %%
df.query("Duration_Min==3.00 and Year>2014")
# Out:
#                     Track_ID                       Track_Name  Duration_Min  \
# 896   6pnD89Q888HUHhcwQUTky8                      Free Animal           3.0
# 1064  2wxfu24GQpEZQrjDJm5Ac1               Every Little Thing           3.0
# 1281  0V4aRCAMBblWlRGTjiyMRR  Fetish Remix (feat. Young Thug)           3.0
#
#                    Artists Release_Date  Year  Query
# 896            Foreign Air    9/23/2016  2016   rock
# 1064          Carly Pearce   10/13/2017  2017    sad
# 1281  Lil Keed, Young Thug    9/14/2018  2018  remix

# %%
col="Year"
df.query(f"{col}>2014")
# Out:
#                     Track_ID  \
# 299   3zHq9ouUJQFQRf3cm1rRLu
# 300   50kpGaPAhYJ3sGmk6vplg0
# 301   7B5Npv8NjjTCzk8PLpU66h
# 302   1D0QeY6vwnZcbiM6iBYYSj
# 303   5h9hkYIBWTZYFRmF6Iz1gt
# ...                      ...
# 1696  2fyDWKsx5904KnZMGllmAv
# 1697  1y2GDXFvtHPbCkHFYg49Gn
# 1698  5UBonaClAZVfzxJNn8nnhh
# 1699  2pgDBO0ZAgvye7joSmdDm8
# 1700  7lidXGPXPYLNThITAOTlkK
#
#                                              Track_Name  Duration_Min  \
# 299   Love Me Like You Do - From "Fifty Shades Of Grey"          4.21
# 300                                       Love Yourself          3.90
# 301                                    Love In The Dark          4.77
# 302                                    Love Like Ghosts          3.73
# 303                                       Love/Paranoia          3.10
# ...                                                 ...           ...
# 1696                                      A Sad Cartoon          5.26
# ...

# %%
df_unique=df.drop_duplicates("Query")

# %%
df_unique
# Out:
#                    Track_ID  \
# 0    6dBUzqjtbnIa1TwYbyw5CM
# 46   5O2P9iiztwhomNh8xkR9lJ
# 93   7t2bFihaDvhIrd2gn2CWJO
# 151  11MyiSGZSYSmhhqwGUTtAq
# 231  1O9D7P7Z1wMJXW19zTXrXi
#
#                                             Track_Name  Duration_Min  \
# 0                                          Lovers Rock          3.57
# 46                                       Night Changes          3.78
# 93   Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mus...          4.05
# 151                                           Sad Girl          5.30
# 231                                            Go Away          3.23
#
#                                              Artists Release_Date  Year  Query
# 0                                            TV Girl     6/5/2014  2014   love
# 46                                     One Direction   11/17/2014  2014  night
# 93   Ty Dolla $ign, The Weeknd, Wiz Khalifa, Mustard    6/10/2014  2014  remix
# ...

# %%
df.query("Query=='rock'")
# Out:
#                     Track_ID            Track_Name  Duration_Min  \
# 231   1O9D7P7Z1wMJXW19zTXrXi               Go Away          3.23
# 232   2vyae4DvSU2gs8OMOGwXF2          Rock or Bust          3.05
# 233   0755vnFQZLSgHHWbR1qCjY                Rocket          6.53
# 234   5hheGdf1cb4rK0FNiedCfK        The Devil in I          5.71
# 235   5fVl28RgREvxVtGSf9OsbK          Meddle About          3.40
# ...                      ...                   ...           ...
# 1580  3fnPv1LRMxENr63afVhaz1      Honky Tonk Women          3.05
# 1581  4GZ3YCkuH0VvTluVLwUp4g    I Just Wanna Shine          3.47
# 1582  1z5YtEopKg5pyjCM3BEsr5      Dead Man Walking          3.12
# 1583  5utAceRFzBzXUkHrkwSklB       LIKE A ROCKSTAR          3.47
# 1584  5icbZiF6lcuEORG0UzMsS2  Every Time You Leave          3.61
#
#                       Artists Release_Date  Year Query
# 231        Weezer, Best Coast    10/1/2014  2014  rock
# 232                     AC/DC   11/28/2014  2014  rock
# ...

# %%
df.query("Query=='love'")
# Out:
#                     Track_ID  \
# 0     6dBUzqjtbnIa1TwYbyw5CM
# 1     5J4ZkQpzMUFojo1CtAZYpn
# 2     2e3Ea0o24lReQFR4FA7yXH
# 3     6nGeLlakfzlBcFdZXteDq7
# 4     5BJSZocnCeSNeYMj3iVqM7
# ...                      ...
# 1611  5cZx05fE3nAdFqXlXPUacZ
# 1612  64LP4oTxEweNfKTCTGLhtg
# 1613  140dx97IbJbQhIMd7AaHeb
# 1614  3JP7KdSVvcX3mTfitBp2Ec
# 1615  4l0Mvzj72xxOpRrp6h8nHi
#
#                                              Track_Name  Duration_Min  \
# 0                                           Lovers Rock          3.57
# 1                                        Love Me Harder          3.94
# 2                                            Love Yourz          3.52
# 3                                            Love Story          5.27
# 4                                         Love Runs Out          3.74
# ...                                                 ...           ...
# 1611                                           Lovesong          9.29
# ...

# %%
df.query("Query=='remix'")
# Out:
#                     Track_ID  \
# 93    7t2bFihaDvhIrd2gn2CWJO
# 94    0zVMzJ37VQNFUNvdxxat2E
# 95    0QBDmhUqCEFtxA6OoAktKC
# 96    3zSCNTXI7Ed0PiidZVmzIe
# 97    62N2JSA0jHmSH7Va9t7hIf
# ...                      ...
# 1682  2uu2aGqA2UblCg581Q7l1g
# 1683  7LE1K0lZyRFZjSlrnm7lfD
# 1684  5ofPzkJ57L6IWXPmnb4f0C
# 1685  6KgYfOQXAJYaKP3ZyRrxyK
# 1686  7kRVWQ1G4o8w3ubfNW2ZHB
#
#                                              Track_Name  Duration_Min  \
# 93    Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mus...          4.05
# 94                   Flawless Remix (feat. Nicki Minaj)          3.91
# 95                 Lonely (feat. Young Scooter) - Remix          3.11
# 96                                     Ignition - Remix          3.10
# 97           Habits (Stay High) - Hippie Sabotage Remix          4.32
# ...                                                 ...           ...
# 1682                                   Caramelo - Remix          3.89
# ...

# %%
df.query("Query=='sad'")
# Out:
#                     Track_ID           Track_Name  Duration_Min  \
# 151   11MyiSGZSYSmhhqwGUTtAq             Sad Girl          5.30
# 152   1JY6B9ILvmRla2IKKRZvnH          Sad Machine          5.84
# 153   1CS7Sd1u5tWkstBhpssyjP    Take Me to Church          4.03
# 154   0ZfByLXCeKchuj7zi1CJ0S         Stolen Dance          5.23
# 155   6cK2sGKIwGoYdh9mMZFqRb         Sadnecessary          4.97
# ...                      ...                  ...           ...
# 1696  2fyDWKsx5904KnZMGllmAv        A Sad Cartoon          5.26
# 1697  1y2GDXFvtHPbCkHFYg49Gn        Sudden Desire          3.13
# 1698  5UBonaClAZVfzxJNn8nnhh    Brown Sleep Noise          4.13
# 1699  2pgDBO0ZAgvye7joSmdDm8  SAD GIRLZ LUV MONEY          3.27
# 1700  7lidXGPXPYLNThITAOTlkK    You should be sad          3.42
#
#               Artists Release_Date  Year Query
# 151      Lana Del Rey     1/1/2014  2014   sad
# 152   Porter Robinson     8/8/2014  2014   sad
# 153            Hozier    9/19/2014  2014   sad
# ...

# %%
df.query("Query=='night'")
# Out:
#                     Track_ID                Track_Name  Duration_Min  \
# 46    5O2P9iiztwhomNh8xkR9lJ             Night Changes          3.78
# 47    3idU3rXoFCEFhAAbPGbwht  The Night Is Still Young          3.79
# 48    4bBrKDo8rchikwZOtmXbIH  The Night Is Still Young          3.79
# 49    1xBRGN41DWx2vwNFY5CvGe             Night Witches          3.02
# 50    6Xa2q0dapj03CsRzmD0Os5               Fight Night          3.60
# ...                      ...                       ...           ...
# 1642  58HvfVOeJY7lUuCqF0m3ly       MIDDLE OF THE NIGHT          3.07
# 1643  1Ynv5ahQNdRRgDGcMVa3Y6              Friday Night          4.10
# 1644  2o7kljiAHz8ypMLVmzmFqg                 Nightcall          4.10
# 1645  5PeMQiULHTknXhyisgOyXu                 Nightmare          3.98
# 1646  4pqfAjOdONW9IGHq5BV328              Nights Alone          3.35
#
#                        Artists Release_Date  Year  Query
# 46               One Direction   11/17/2014  2014  night
# ...

# %%
year1_release=df.query("2014 < Year <2016")

# %%
year1_release
# Out:
#                    Track_ID  \
# 299  3zHq9ouUJQFQRf3cm1rRLu
# 300  50kpGaPAhYJ3sGmk6vplg0
# 301  7B5Npv8NjjTCzk8PLpU66h
# 302  1D0QeY6vwnZcbiM6iBYYSj
# 303  5h9hkYIBWTZYFRmF6Iz1gt
# ..                      ...
# 590  4Fx8dpPrAtwSlg1XEwxMUF
# 591  07BuyVse8pYAWd9DXD7B2D
# 592  6hvSILCCQT5a0MRcOE36zd
# 593  1SmoikQyzvAi35I5X4LHMY
# 594  3vtFowc9zcQfvqsLAZ9Cx2
#
#                                             Track_Name  Duration_Min  \
# 299  Love Me Like You Do - From "Fifty Shades Of Grey"          4.21
# 300                                      Love Yourself          3.90
# 301                                   Love In The Dark          4.77
# 302                                   Love Like Ghosts          3.73
# 303                                      Love/Paranoia          3.10
# ..                                                 ...           ...
# 590                                          Dern Kala          3.66
# ...

# %%
df.isnull().sum()
# Out:
# Track_ID        0
# Track_Name      0
# Duration_Min    0
# Artists         0
# Release_Date    0
# Year            0
# Query           0
# dtype: int64

# %%
new_df=df.dropna

# %%
new_df=df.dropna(axis=1)

# %%
new_df.shape
# Out:
# (1701, 7)

# %%
new_df.drop_duplicates()
# Out:
#                     Track_ID           Track_Name  Duration_Min  \
# 0     6dBUzqjtbnIa1TwYbyw5CM          Lovers Rock          3.57
# 1     5J4ZkQpzMUFojo1CtAZYpn       Love Me Harder          3.94
# 2     2e3Ea0o24lReQFR4FA7yXH           Love Yourz          3.52
# 3     6nGeLlakfzlBcFdZXteDq7           Love Story          5.27
# 4     5BJSZocnCeSNeYMj3iVqM7        Love Runs Out          3.74
# ...                      ...                  ...           ...
# 1696  2fyDWKsx5904KnZMGllmAv        A Sad Cartoon          5.26
# 1697  1y2GDXFvtHPbCkHFYg49Gn        Sudden Desire          3.13
# 1698  5UBonaClAZVfzxJNn8nnhh    Brown Sleep Noise          4.13
# 1699  2pgDBO0ZAgvye7joSmdDm8  SAD GIRLZ LUV MONEY          3.27
# 1700  7lidXGPXPYLNThITAOTlkK    You should be sad          3.42
#
#                         Artists Release_Date  Year Query
# 0                       TV Girl     6/5/2014  2014  love
# 1     Ariana Grande, The Weeknd    8/22/2014  2014  love
# ...

# %%
new_df.duplicated("Query")
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1696     True
# 1697     True
# 1698     True
# 1699     True
# 1700     True
# Length: 1701, dtype: bool

# %%
new_df=df.drop(["Track_ID","Release_Date"], axis=1)

# %%
new_df.query("Artists=='Ariana Grande'")
# Out:
#           Track_Name  Duration_Min        Artists  Year  Query
# 1215  goodnight n go          3.16  Ariana Grande  2018  night
# 1317         ghostin          4.52  Ariana Grande  2018    sad
# 1508         ghostin          4.52  Ariana Grande  2019    sad

# %%
df_artists= df.drop_duplicates(["Artists"])

# %%
df_artists
# Out:
#                     Track_ID               Track_Name  Duration_Min  \
# 0     6dBUzqjtbnIa1TwYbyw5CM              Lovers Rock          3.57
# 1     5J4ZkQpzMUFojo1CtAZYpn           Love Me Harder          3.94
# 2     2e3Ea0o24lReQFR4FA7yXH               Love Yourz          3.52
# 3     6nGeLlakfzlBcFdZXteDq7               Love Story          5.27
# 4     5BJSZocnCeSNeYMj3iVqM7            Love Runs Out          3.74
# ...                      ...                      ...           ...
# 1695  0Al3wN3keprGTSgG8NBwjr  I Hope You’re Happy Now          3.31
# 1696  2fyDWKsx5904KnZMGllmAv            A Sad Cartoon          5.26
# 1697  1y2GDXFvtHPbCkHFYg49Gn            Sudden Desire          3.13
# 1698  5UBonaClAZVfzxJNn8nnhh        Brown Sleep Noise          4.13
# 1699  2pgDBO0ZAgvye7joSmdDm8      SAD GIRLZ LUV MONEY          3.27
#
#                         Artists Release_Date  Year Query
# 0                       TV Girl     6/5/2014  2014  love
# ...

# %%
df_artists.shape
# Out:
# (1240, 7)

# %%
new_df.dtypes
# Out:
# Track_Name       object
# Duration_Min    float64
# Artists          object
# Year              int64
# Query            object
# dtype: object

# %%
new_df=new_df.sort_values("Duration_Min",)

# %%
new_df
# Out:
#                                              Track_Name  Duration_Min  \
# 896                                         Free Animal          3.00
# 1281                    Fetish Remix (feat. Young Thug)          3.00
# 1064                                 Every Little Thing          3.00
# 1177                    Love Hurts (feat. Travis Scott)          3.01
# 1108                                       Highway Tune          3.01
# ...                                                 ...           ...
# 518   Sleep and Relaxation Nature Sounds, Crickets S...         20.00
# 384                               A Night in the Forest         20.00
# 364                            Night Time Forest Sounds         20.00
# 779                             White Noise 2 Hour Long        120.01
# 769                             White Noise 3 Hour Long        180.47
#
#                           Artists  Year  Query
# 896                   Foreign Air  2016   rock
# ...
